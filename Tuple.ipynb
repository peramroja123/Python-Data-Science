# %% [markdown]
# #Tuple-> user can pass anything inside the tuple-> int|float|str|bool
# ##Indexing|memory allocation|slicing|skipping are same as string,list

# %%
a='data'
print(type(a))
# Out:
# <class 'str'>

# %%
a=[10,20]
print(type(a))
# Out:
# <class 'list'>

# %%
a=(10,55.5,'data')
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=(10,4,17,9,21,36)
print(a)
# Out:
# (10, 4, 17, 9, 21, 36)

# %%
print(a[::3])
# Out:
# (10, 9)

# %%
print(a[2])
# Out:
# 17

# %%
print(a[1:4])
# Out:
# (4, 17, 9)

# %% [markdown]
# #Tuple is Mutable

# %%
#add
a=(10,4,17,9,21,36)
a[6]=500
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b90d7946325f> in <cell line: 3>()
#       1 #add
#       2 a=(10,4,17,9,21,36)
# ----> 3 a[6]=500
#       4 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#del
a=(10,4,17,9,21,36)
del a[4]
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f3b008182fce> in <cell line: 3>()
#       1 #del
#       2 a=(10,4,17,9,21,36)
# ----> 3 del a[4]
#       4 print(a)
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# #Built_in_functions->2
# ##1.Count
# ##2.index

# %%
#count
a=(10,4,17,9,21,36)
print(a.count(4))
# Out:
# 1

# %%
#index
print(a.index(17))
# Out:
# 2

# %%
#tuple stores multiple values in a single variable
a=100,200
print(a)
# Out:
# (100, 200)

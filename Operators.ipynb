# %%
#Addition
10+20
# Out:
# 30

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
#sub
print(a-b)
# Out:
# 10

# %%
a=20
b=10
print(a-b)
# Out:
# 10

# %%
#Mul
a=4
b=5
print(a*b)
# Out:
# 20

# %%
#div(Quotient)
a=22
b=5
print(a/b)
# Out:
# 4.4

# %%
#floor div
a=22
b=5
print(a//b)
# Out:
# 4

# %%
# %mod(remainder)
a=23
b=4
print(a%b)
# Out:
# 3

# %%
#square
a=5
print(a*a)
# Out:
# 25

# %%
#cube
a*a*a
# Out:
# 125

# %%
#** power
a=2
b=5
print(a**b)
# Out:
# 32

# %%
#pow built in function
pow(2,5)
# Out:
# 32

# %%
#we have 3 arguments like (x,y,z)
#x=base
#y=exponent
#z=optional,modules
pow(4,3,5)
# Out:
# 4

# %%
#greater
a=10
b=5
print(a>b)
# Out:
# True

# %%
print(a<b)
# Out:
# False

# %%
#less than
a=10
b=5
print(a<b)
# Out:
# False

# %%
print(a>b)
# Out:
# True

# %%
print(a>=b)
# Out:
# True

# %%
a=10
print(a)
# Out:
# 10

# %%
#equals
a=10
b=10
print(a==b)
# Out:
# True

# %%
print(a!=b)
# Out:
# False

# %% [markdown]
# # - `and,or operators`
# and
# t t ->t
# f f->f
# t f->f
# f t->f

# %%
10>=11 and 20<=32
# Out:
# False

# %% [markdown]
# #or
# t t -> t
# f f -> f
# t f -> t
# f t -> t

# %%
10>=11 or 20<=32
# Out:
# True
